# %%
if test expression:
    statement(s)
# Out:
#   File "<ipython-input-1-b15a120f988e>", line 1
#     if test expression:
#             ^
# SyntaxError: invalid syntax

# %%
num=int(input("Enter: "))
if num>=2:
    print("the number is greater than 2")

# %%
if test expression:
    Body of if
else:
    Body of else

# %% [markdown]
# ![If-Else-in-Python.jpg](attachment:If-Else-in-Python.jpg)

# %%
# Program checks if the number is positive or negative
# And displays an appropriate message

num = -7

# Try these two variations as well. 
# num = -5
# num = 0

if num >= 0:
    print("Positive or Zero")
else:
    print("Negative number")

# %%
if test expression:
    Body of if
elif test expression:
    Body of elif
else: 
    Body of else
# Out:
#   File "<ipython-input-2-c18521d29780>", line 1
#     if test expression:
#             ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![if%20elif%20else%20stmt%20python.png](attachment:if%20elif%20else%20stmt%20python.png)

# %% [markdown]
#  == eqaul to
#     >= greater than equal to
#     <= less than equal to
#     != not equal to
#     % remainder
#     / division

# %%
age=int(input("Enter your age:"))
if age<30:
    print("you are young!")
elif age>30 and age<60:
    print("You are adult!")
else:
    print("You are old!")
# Out:
# Enter your age:25
# you are young!

# %%
num = 0

if num > 0:
    print("Positive number")
elif num == 0:
    print("Zero")
else:
    print("Negative number")
# Out:
# Zero

# %% [markdown]
# 1- Number is odd or even
# print result-
# () is even/odd
#
# 2- if the year is leap year
# () is a leap year/not a leap year
#
# 3- take 3 values from user
# find out the largest number
# print result
# largest number is ()
#
# 4-create a list with 8 names of vegetables
# reverse the list
# add 2 new values at index 2 and 4
# count the elements of the list
# sort the list apphabetically
# sort the list descending
# pop the list with one new value
