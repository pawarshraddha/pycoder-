# %% [markdown]
# ## Name :- Shraddha Pandit Pawar

# %% [markdown]
# ###  Importing libraries and data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_excel("SampleSuperstore.csv.xlsx")
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# ### Introductory Details About Data

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0      42420.0  South        Furniture    Bookcases  261.9600       2.0
# 1      42420.0  South        Furniture       Chairs  731.9400       3.0
# 2      90036.0   West  Office Supplies       Labels   14.6200       2.0
# 3      33311.0  South        Furniture       Tables  957.5775       5.0
# 4      33311.0  South  Office Supplies      Storage   22.3680       2.0
#
#    Discount    Profit Profit/Loss
# 0      0.00   41.9136      Profit
# ...

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989      33180.0  South        Furniture  Furnishings   25.248       3.0
# 9990      92627.0   West        Furniture  Furnishings   91.960       2.0
# 9991      92627.0   West       Technology       Phones  258.576       2.0
# 9992      92627.0   West  Office Supplies        Paper   29.600       4.0
# 9993      92683.0   West  Office Supplies   Appliances  243.160       2.0
#
#       Discount   Profit Profit/Loss
# 9989       0.2   4.1028      Profit
# ...

# %%
df.shape
# Out:
# (9994, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   float64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   float64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
#  13  Profit/Loss   9994 non-null   object
# dtypes: float64(5), object(9)
# memory usage: 1.1+ MB

# %%
print(df.columns)
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Profit/Loss'],
#       dtype='object')

# %% [markdown]
# ### Statistical Insights

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# ### Data cleaning- Checking for null values

# %% [markdown]
# checking missing values

# %%
df.isna().sum           #gives the number of missing values for each variable
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of       Ship Mode  Segment  Country   City  State  Postal Code  Region  \
# 0         False    False    False  False  False        False   False
# 1         False    False    False  False  False        False   False
# 2         False    False    False  False  False        False   False
# 3         False    False    False  False  False        False   False
# 4         False    False    False  False  False        False   False
# ...         ...      ...      ...    ...    ...          ...     ...
# 9989      False    False    False  False  False        False   False
# 9990      False    False    False  False  False        False   False
# 9991      False    False    False  False  False        False   False
# 9992      False    False    False  False  False        False   False
# 9993      False    False    False  False  False        False   False
#
#       Category  Sub-Category  Sales  Quantity  Discount  Profit  Profit/Loss
# ...

# %% [markdown]
# Removing Null Entries

# %%
df.dropna(axis=0,inplace=True)    #  If null entries are there

# %%
df.shape
# Out:
# (9994, 14)

# %% [markdown]
# ### Data cleaning- Checking for null values

# %% [markdown]
# checking missing values

# %%
df.isna().sum           #gives the number of missing values for each variable
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of       Ship Mode  Segment  Country   City  State  Postal Code  Region  \
# 0         False    False    False  False  False        False   False
# 1         False    False    False  False  False        False   False
# 2         False    False    False  False  False        False   False
# 3         False    False    False  False  False        False   False
# 4         False    False    False  False  False        False   False
# ...         ...      ...      ...    ...    ...          ...     ...
# 9989      False    False    False  False  False        False   False
# 9990      False    False    False  False  False        False   False
# 9991      False    False    False  False  False        False   False
# 9992      False    False    False  False  False        False   False
# 9993      False    False    False  False  False        False   False
#
#       Category  Sub-Category  Sales  Quantity  Discount  Profit  Profit/Loss
# ...

# %% [markdown]
# ### Removing Null Entries

# %%
df.dropna(axis=0,inplace=True)    #  If null entries are there

# %%
df.shape
# Out:
# (9994, 14)

# %% [markdown]
# ### Filling values in place of Null Entries(If Numerical feature)
# Values can either be mean, median or any integer

# %% [markdown]
# ### Handling Outliers

# %%
sns.boxplot(data=df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Sales and Profit having more outliers
# so we can remove it

# %%
sns.boxplot(x='Sales' ,data=df)
# Out:
# <AxesSubplot:xlabel='Sales'>

# %% [markdown]
# This outlier are remove by using IQR tec

# %%
# IQR
Q1 = np.percentile(df['Sales'], 25,
                interpolation = 'midpoint')
  
Q3 = np.percentile(df['Sales'], 75,
                interpolation = 'midpoint')
IQR = Q3 - Q1


print("Old Shape: ", df.shape)
  
# Upper bound
upper = np.where(df['Sales'] >= (Q3+1.5*IQR))
  
# Lower bound
lower = np.where(df['Sales'] <= (Q1-1.5*IQR))
  
# Removing the Outliers
df.drop(upper[0], inplace = True)
df.drop(lower[0], inplace = True)
  
print("New Shape: ", df.shape)
  
sns.boxplot(x='Sales', data=df)
# Out:
# Old Shape:  (9994, 14)
# New Shape:  (8827, 14)
# <AxesSubplot:xlabel='Sales'>

# %%
sns.boxplot(x='Profit' ,data=df)
# Out:
# <AxesSubplot:xlabel='Profit'>

# %%
# IQR
Q1 = np.percentile(df['Profit'], 25,
                interpolation = 'midpoint')
  
Q3 = np.percentile(df['Profit'], 75,
                interpolation = 'midpoint')
IQR = Q3 - Q1


print("Old Shape: ", df.shape)
  
# Upper bound
upper = np.where(df['Profit'] >= (Q3+1.5*IQR))
  
# Lower bound
lower = np.where(df['Profit'] <= (Q1-1.5*IQR))
  
# Removing the Outliers
df.drop(upper[0], inplace = True)
df.drop(lower[0], inplace = True)
  
print("New Shape: ", df.shape)
  
sns.boxplot(x='Profit', data=df)
# Out:
# Old Shape:  (8827, 14)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-a41d7a7ab293> in <module>
#      17
#      18 # Removing the Outliers
# ---> 19 df.drop(upper[0], inplace = True)
#      20 df.drop(lower[0], inplace = True)
#      21
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4899                 weight  1.0     0.8
#    4900         """
# -> 4901         return super().drop(
#    4902             labels=labels,
#    4903             axis=axis,
#
# ...

# %% [markdown]
# ### Data Visualization

# %%
sns.countplot(x='Ship Mode',data=df,palette='magma')
plt.show()

# %% [markdown]
# we can concluded that standard class is best for shiping

# %%
sns.countplot(x='Ship Mode',hue='Category', data=df , palette='magma' )
plt.title('countplot')
plt.show()

# %%
sns.countplot(x='Category',hue='Sub-Category', data=df , palette='magma' )
plt.title('countplot')
plt.show()

# %% [markdown]
# ### Bivariate Analysis - Scatter plot

# %%
sns.scatterplot(x='Region', y='Profit',
                hue='Category', data=df, )
plt.title('Profit')
plt.show()

# %%
sns.scatterplot(x='Quantity', y='Profit',
                hue='Category', data=df, )
plt.title('Profit')
plt.show()

# %% [markdown]
# We can conclude that if quntity is more then our loss is less

# %%
sns.scatterplot(x='Quantity', y='Sales',
                hue='Category', data=df, )
plt.title('Profit')
plt.show()

# %%
sns.scatterplot(x='Quantity', y='Discount',
                hue='Category', data=df, )
plt.title('Profit')
plt.show()

# %% [markdown]
# Office suppliers have more discount than other two

# %%
sns.scatterplot(x='Discount', y='Profit',
                hue='Category', data=df, )
plt.title('Profit')
plt.show()

# %% [markdown]
# If we get more discount then we are in loss

# %%
sns.scatterplot(x='Discount', y='Sales',
                hue='Category', data=df, )
plt.title('Profit')
plt.show()

# %%
sns.scatterplot(x='Ship Mode', y='Quantity',
                hue='Category', data=df, )
plt.title('Profit')
plt.show()

# %%
sns.scatterplot(x='Sales', y='Profit',
                hue='Category', data=df, )
plt.title('Profit')
plt.show()

# %% [markdown]
# ### Pair Plot - Multivariate Analysis

# %%
sns.set_style("ticks")
sns.pairplot(df,hue = 'Category',diag_kind = "kde",kind = "scatter",palette = "husl")
plt.show()

# %%
sns.set_style("ticks")
sns.pairplot(df,hue = 'Quantity',diag_kind = "kde",kind = "scatter",palette = "husl")
plt.show()

# %% [markdown]
# ### Histograms with Distplot Plot

# %%
plot = sns.FacetGrid(df , hue="Category")
plot.map(sns.distplot, "Profit").add_legend()
  

plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
plot = sns.FacetGrid(df , hue="Category")
plot.map(sns.distplot, "Sales").add_legend()
  

plt.show()
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %% [markdown]
# ### Handling Correlation

# %%
corr=df.corr()
corr
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000  0.005842  0.018717  0.052600 -0.031287
# Sales           0.005842  1.000000  0.161537 -0.075480  0.196448
# Quantity        0.018717  0.161537  1.000000  0.017105  0.094351
# Discount        0.052600 -0.075480  0.017105  1.000000 -0.457813
# Profit         -0.031287  0.196448  0.094351 -0.457813  1.000000

# %%
sns.heatmap(corr,annot=True,linewidths=.5,cmap="YlGnBu")
# Out:
# <AxesSubplot:>
