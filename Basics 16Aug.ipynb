# %% [markdown]
# ![titanic.jpg](attachment:titanic.jpg)

# %%
from PIL import Image       #python imaging library
img=Image.open('new2.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2048x2048 at 0x24941072910>

# %%
import pandas as pd       #pandas library imported

# %%
zoo=pd.read_csv('zoo.csv')     #imported the zoo data

# %%
zoo.head(20)                  #first few rows of data
# Out:
#    animal_name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0     aardvark     1         0     0     1         0        0         1
# 1     antelope     1         0     0     1         0        0         0
# 2         bass     0         0     1     0         0        1         1
# 3         bear     1         0     0     1         0        0         1
# 4         boar     1         0     0     1         0        0         1
# 5      buffalo     1         0     0     1         0        0         0
# 6         calf     1         0     0     1         0        0         0
# 7         carp     0         0     1     0         0        1         0
# 8      catfish     0         0     1     0         0        1         1
# 9         cavy     1         0     0     1         0        0         0
# 10     cheetah     1         0     0     1         0        0         1
# 11     chicken     0         1     1     0         1        0         0
# ...

# %%
zoo.tail(20)           #last rows of the data
# Out:
#     animal_name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 81         slug     0         0     1     0         0        0         0
# 82         sole     0         0     1     0         0        1         0
# 83      sparrow     0         1     1     0         1        0         0
# 84     squirrel     1         0     0     1         0        0         0
# 85     starfish     0         0     1     0         0        1         1
# 86     stingray     0         0     1     0         0        1         1
# 87         swan     0         1     1     0         1        1         0
# 88      termite     0         0     1     0         0        0         0
# 89         toad     0         0     1     0         0        1         0
# 90     tortoise     0         0     1     0         0        0         0
# 91      tuatara     0         0     1     0         0        0         1
# 92         tuna     0         0     1     0         0        1         1
# ...

# %%
data=pd.read_csv('Salary_Data.csv') #imported salary data

# %%
data
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
data.info()             #info about the data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
data.shape           #shape
# Out:
# (30, 2)

# %%
data.describe()    #description of the data
# Out:
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
A=input("Enter the value: ")  #asking user to give values
B=input("Enter the value: ")
print(type(A))
print(type(B))
A=(A + B)                #accepting as a string
print(A)
# Out:
# Enter the value: 12
# Enter the value:23
# <class 'str'>
# <class 'str'>
# 1223

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy

# %%
pip install scipy

# %%
pip install matplotlib

# %%
pip install scikit-learn

# %%
pip install --upgrade pip
# Out:
# ...
#
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 20.1.1
#     Uninstalling pip-20.1.1:
#       Successfully uninstalled pip-20.1.1
# ...

# %%
import pandas as pd 
print(pd.__version__)
# Out:
# 1.0.5

# %%
import numpy
print(numpy.__version__)
# Out:
# 1.18.5

# %%
import scipy
print(scipy.__version__)
# Out:
# 1.5.0

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 0.23.1

# %%
import random

print(random.randint(0,100))
# Out:
# 22

# %%
x = 5
y = 10

x, y = y, x                    #swapping variables
print("x =", x)
print("y =", y)
# Out:
# x = 10
# y = 5

# %%
list = ["Happy", [2, 0, 1, 5],[2,3,4]]             #mixed nested list
print(list)
print(list[0])
print(list[0][4])
# Out:
# ['Happy', [2, 0, 1, 5], [2, 3, 4]]
# Happy
# y

# %%
list = ["Happy", [2, 0, 1, 5],[2,3,4],"Python",[45,56,78],"is easy to learn","keep going!"]  
list[0:3]                                           #list slicing           
list[0:7:2]                                         #"Happy",[2,3,4],[45,56,78]
# Out:
# ['Happy', [2, 3, 4], [45, 56, 78], 'keep going!']

# %%
list = ["Language", [2, 0, 1, 5],"Python",[2,3,4],"is easy to learn",[45,56,78],"keep going!"]  
                                                                     #list slicing          
list[0:6:2]                                         #"Happy",[2,3,4],[45,56,78]
# Out:
# ['Language', 'Python', 'is easy to learn']

# %%
list = ["Language", [2, 0, 1, 5],"Python",[2,3,[3.4,6.7],4],"is easy to learn",[45,56,78],"keep going!"] 

print(list[3][2][1])
# Out:
# 6.7

# %%
list = ["Happy", [2, 0, 1, 5],[2,3,4],"Python",[45,56,78],"is easy to learn"]                                   #mixed nested list

print(list[2][1])             #list indexing
# Out:
# 3
